# %% [markdown]
# # LAB | Extractive Question Answering

# %% [markdown]
# This notebook demonstrates how Pinecone helps you build an extractive question-answering application. To build an extractive question-answering system, we need three main components:
#
# - A vector index to store and run semantic search
# - A retriever model for embedding context passages
# - A reader model to extract answers
#
# We will use the SQuAD dataset, which consists of **questions** and **context** paragraphs containing question **answers**. We generate embeddings for the context passages using the retriever, index them in the vector database, and query with semantic search to retrieve the top k most relevant contexts containing potential answers to our question. We then use the reader model to extract the answers from the returned contexts.

# %% [markdown]
# Let's get started by installing the packages needed for notebook to run:

# %% [markdown]
# Install Dependencies

# %%
# ── Pinned dependencies ──────────────────────────────────────────────────────
# Install all interdependent packages in one command so pip resolves them
# together, avoiding binary incompatibility errors at import time.
# After running this cell: Runtime → Restart runtime, then continue.
# !pip install \
    numpy==1.26.4 \
    datasets==2.14.7 \
    huggingface_hub==0.21.4 \
    transformers==4.38.2 \
    sentence-transformers==2.6.1 \
    tokenizers==0.15.2 \
    pinecone \
    tqdm \
    --quiet

# %%
import os
from pinecone import Pinecone, ServerlessSpec

# ── Step 1: Try to load the API key from Colab Secrets ──────────────────────
# google.colab only exists when running inside Colab, so we guard the import
# with a try/except to keep the notebook portable to other environments.
try:
    from google.colab import userdata
    pinecone_api_key = userdata.get("PINECONE_API_KEY")  # matches the secret name you set in Colab
except Exception:
    # We're not in Colab, or the secret hasn't been added yet — that's fine
    pinecone_api_key = None

# ── Step 2: Fall back to environment variable or manual input ────────────────
if not pinecone_api_key:
    # Maybe it was already set earlier in the session via os.environ
    pinecone_api_key = os.getenv("PINECONE_API_KEY")

if not pinecone_api_key:
    # Last resort: prompt the user manually (works in any environment)
    import getpass
    pinecone_api_key = getpass.getpass("Pinecone API key not found in secrets. Enter it manually: ")

# ── Step 3: Store in environment and verify ──────────────────────────────────
os.environ["PINECONE_API_KEY"] = pinecone_api_key

print(f"Pinecone API Key loaded: {pinecone_api_key[:4]}...{pinecone_api_key[-4:]}")
# Out:
# Pinecone API Key loaded: pcsk...48ok

# %% [markdown]
# # Load Dataset

# %% [markdown]
# Now let's load the SQUAD dataset from the HuggingFace Model Hub. We load the dataset into a pandas dataframe and filter the title, question, and context columns, and we drop any duplicate context passages.

# %%
from datasets import load_dataset

# load the squad dataset into a pandas dataframe
df = load_dataset("squad", split="train").to_pandas()
# Out:
# ...
# Generating validation split:   0%|          | 0/10570 [00:00<?, ? examples/s]

# %%
# Keep only the columns relevant for our retrieval pipeline.
# 'title' gives us traceable metadata; 'context' is what we embed.
df = df[['title', 'context']]

# SQuAD has multiple questions per passage, so the same context paragraph
# appears repeatedly. drop_duplicates() keeps only the first occurrence
# of each unique context string, giving us one vector per passage.
df = df.drop_duplicates(subset='context')
df
# Out:
#                           title  \
# 0      University_of_Notre_Dame
# 5      University_of_Notre_Dame
# 10     University_of_Notre_Dame
# 15     University_of_Notre_Dame
# 20     University_of_Notre_Dame
# ...                         ...
# 87574                 Kathmandu
# 87579                 Kathmandu
# 87584                 Kathmandu
# 87589                 Kathmandu
# 87594                 Kathmandu
#
#                                                  context
# 0      Architecturally, the school has a Catholic cha...
# 5      As at most other universities, Notre Dame's st...
# 10     The university is the major seat of the Congre...
# 15     The College of Engineering was established in ...
# 20     All of Notre Dame's undergraduate students are...
# ...                                                  ...
# 87574  Institute of Medicine, the central college of ...
# 87579  Football and Cricket are the most popular spor...
# ...

# %% [markdown]
# # Initialize Pinecone Index

# %% [markdown]
# The Pinecone index stores vector representations of our context passages which we can retrieve using another vector (query vector). We first need to initialize our connection to Pinecone to create our vector index. For this, we need a free [API key]("https://app.pinecone.io/"), and then we initialize the connection like so:

# %%
from pinecone import ServerlessSpec

spec = ServerlessSpec(
    cloud="aws", region="us-east-1"
)

# connect to pinecone environment
pc = Pinecone(api_key=pinecone_api_key, environment=spec.region)

# %% [markdown]
# Now we create a new index called "question-answering" — we can name the index anything we want. We specify the metric type as "cosine" and dimension as 384 because the retriever we use to generate context embeddings is optimized for cosine similarity and outputs 384-dimension vectors.

# %%
index_name = 'question-answering'

import time

# Check if index exists & create with ServerlessSpec
if index_name not in pc.list_indexes().names():
    #create the index if it does not exist
    pc.create_index(
        name=index_name,
        dimension=384,
        metric='cosine',
        spec=spec
    )
    # wait for the indext to be ready before we try to use it
    while not pc.describe_index(index_name).status['ready']:
      time.sleep(1)
# connect to the index so we can interact with it
index = pc.Index(index_name)

# verify the index is empty (stats should show 0 vectors)
print(index.describe_index_stats())
# Out:
# {'_response_info': {'raw_headers': {'connection': 'keep-alive',
#                                     'content-length': '185',
#                                     'content-type': 'application/json',
#                                     'date': 'Tue, 24 Feb 2026 16:48:23 GMT',
#                                     'grpc-status': '0',
#                                     'server': 'envoy',
#                                     'x-envoy-upstream-service-time': '42',
#                                     'x-pinecone-request-latency-ms': '42',
#                                     'x-pinecone-response-duration-ms': '44'}},
#  'dimension': 384,
#  'index_fullness': 0.0,
#  'memoryFullness': 0.0,
#  'metric': 'cosine',
#  'namespaces': {'__default__': {'vector_count': 320}},
#  'storageFullness': 0.0,
#  'total_vector_count': 320,
#  'vector_type': 'dense'}

# %% [markdown]
# # Initialize Retriever

# %% [markdown]
# Next, we need to initialize our retriever. The retriever will mainly do two things:
#
# - Generate embeddings for all context passages (context vectors/embeddings)
# - Generate embeddings for our questions (query vector/embedding)
#
# The retriever will generate embeddings in a way that the questions and context passages containing answers to our questions are nearby in the vector space. We can use cosine similarity to calculate the similarity between the query and context embeddings to find the context passages that contain potential answers to our question.
#
# We will use a SentenceTransformer model named ``multi-qa-MiniLM-L6-cos-v1`` designed for semantic search and trained on 215M (question, answer) pairs from diverse sources as our retriever.

# %%
import torch
from sentence_transformers import SentenceTransformer

# Set device to GPU if available
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(f"Using device: {device}")

# Load retriever model (multi-qa-MiniLM-L6-cos-v1 - 384 dimensions)
retriever = SentenceTransformer('multi-qa-MiniLM-L6-cos-v1', device=device) #use the 'multi-qa-MiniLM-L6-cos-v1' model from HuggingFace to build the retriever

# ✅ Now retriever is loaded and ready
print("Retriever model loaded:", retriever)
# Out:
# Using device: cuda
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/383 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Retriever model loaded: SentenceTransformer(
#   (0): Transformer({'max_seq_length': 512, 'do_lower_case': False}) with Transformer model: BertModel
# ...

# %% [markdown]
# # Generate Embeddings and Upsert

# %% [markdown]
# Next, we need to generate embeddings for the context passages. We will do this in batches to help us more quickly generate embeddings and upload them to the Pinecone index. When passing the documents to Pinecone, we need an id (a unique value), context embedding, and metadata for each document representing context passages in the dataset. The metadata is a dictionary containing data relevant to our embeddings, such as the article title, context passage, etc.

# %%
from tqdm.auto import tqdm

# we will use batches of 64
batch_size = 64

for i in tqdm(range(0, len(df), batch_size)):
    # find end of batch
    i_end = min(i + batch_size, len(df))
    # extract batch
    batch = df.iloc[i:i_end]
    # generate embeddings for batch — returns a numpy array, .tolist() converts
    # it to plain Python lists which Pinecone's client expects
    embeds = retriever.encode(batch['context'].tolist()).tolist()
    # get metadata — stored alongside each vector so we can retrieve the
    # original text and title when querying, not just the vector ID
    metadata = [
        {
            'title': row['title'],
            'context': row['context']
        }
        for _, row in batch.iterrows()
    ]
    # create unique IDs by converting the row indices to strings
    ids = [str(x) for x in range(i, i_end)]
    # zip ids, vectors, and metadata into Pinecone's expected (id, vector, metadata) format
    to_upsert = list(zip(ids, embeds, metadata))
    # upsert/insert these records to pinecone
    _ = index.upsert(vectors=to_upsert)

# check that we have all vectors in index
index.describe_index_stats()
# Out:
#   0%|          | 0/296 [00:00<?, ?it/s]
# {'_response_info': {'raw_headers': {'connection': 'keep-alive',
#                                     'content-length': '189',
#                                     'content-type': 'application/json',
#                                     'date': 'Tue, 24 Feb 2026 16:52:10 GMT',
#                                     'grpc-status': '0',
#                                     'server': 'envoy',
#                                     'x-envoy-upstream-service-time': '13',
#                                     'x-pinecone-request-latency-ms': '13',
#                                     'x-pinecone-response-duration-ms': '15'}},
#  'dimension': 384,
#  'index_fullness': 0.0,
#  'memoryFullness': 0.0,
#  'metric': 'cosine',
#  'namespaces': {'__default__': {'vector_count': 18891}},
#  'storageFullness': 0.0,
#  'total_vector_count': 18891,
#  'vector_type': 'dense'}

# %% [markdown]
# # Initialize Reader

# %% [markdown]
# We use the `deepset/electra-base-squad2` model from the HuggingFace model hub as our reader model. We load this model into a "question-answering" pipeline from HuggingFace transformers and feed it our questions and context passages individually. The model gives a prediction for each context we pass through the pipeline.

# %%
from transformers import pipeline

model_name = 'deepset/electra-base-squad2'
# load the reader model into a question-answering pipeline
reader = pipeline(tokenizer=model_name, model=model_name, task='question-answering', device=device)
reader
# Out:
# config.json:   0%|          | 0.00/635 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/436M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/200 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]

# %% [markdown]
# Now all the components we need are ready. Let's write some helper functions to execute our queries. The `get_context` function retrieves the context embeddings containing answers to our question from the Pinecone index, and the `extract_answer` function extracts the answers from these context passages.

# %%
# gets context passages from the pinecone index

def get_context(question, top_k):

    # embed the question into the same 384-dim space as our stored passages
    xq = retriever.encode([question]).tolist()

    # query Pinecone for the top_k passages whose vectors are closest
    # to the question vector — include_metadata=True is essential so we
    # can recover the original passage text, not just vector IDs
    xc = index.query(vector=xq, top_k=top_k, include_metadata=True)

    # extract just the context strings from the Pinecone result structure
    # xc['matches'] is a list of match objects, each with a 'metadata' dict
    # that contains the 'context' key we stored during upsert

    c = [x['metadata']['context'] for x in xc['matches']]

    return c

# %%
from pprint import pprint

# extracts answer from the context passage
def extract_answer(question, context):
    results = []
    for c in context:
        # feed the reader the question and contexts to extract answers
        answer = reader(question=question, context=c)
        # add the context to answer dict for printing both together
        answer["context"] = c
        results.append(answer)
    # sort the result based on the score from reader model
    results = sorted(results, key=lambda x: x['score'], reverse=True)

    # ── Pretty print ────────────────────────────────────────────────────────
    print(f"\n{'='*60}")
    print(f"  QUESTION: {question}")
    print(f"{'='*60}")

    for rank, result in enumerate(results, start=1):
        answer_text = result['answer']
        score = result['score']
        ctx = result['context']
        start = result['start']
        end = result['end']

        print(f"\n  Rank #{rank}  |  Confidence: {score:.2%}")
        print(f"  Answer: {answer_text}")
        print(f"\n  Context (answer highlighted between --> <--):")

        # Highlight the exact answer span inside the context passage
        # by inserting markers around the start:end character positions
        highlighted = ctx[:start] + f" -->{answer_text}<-- " + ctx[end:]

        # Word-wrap the context at 70 chars so it's readable in the output
        import textwrap
        wrapped = textwrap.fill(highlighted, width=70)
        print(textwrap.indent(wrapped, prefix="    "))
        print(f"\n  {'-'*56}")

# %%
question = "How much oil is Egypt producing in a day?"

context = get_context(question, top_k = 3)

pprint(context)
# Out:
# ['Egypt was producing 691,000 bbl/d of oil and 2,141.05 Tcf of natural gas (in '
#  '2013), which makes Egypt as the largest oil producer not member of the '
#  'Organization of the Petroleum Exporting Countries (OPEC) and the '
#  'second-largest dry natural gas producer in Africa. In 2013, Egypt was the '
#  'largest consumer of oil and natural gas in Africa, as more than 20% of total '
#  'oil consumption and more than 40% of total dry natural gas consumption in '
#  'Africa. Also, Egypt possesses the largest oil refinery capacity in Africa '
#  '726,000 bbl/d (in 2012). Egypt is currently planning to build its first '
#  'nuclear power plant in El Dabaa city, northern Egypt.',
#  'Egypt has a developed energy market based on coal, oil, natural gas, and '
#  'hydro power. Substantial coal deposits in the northeast Sinai are mined at '
#  'the rate of about 600,000 tonnes (590,000 long tons; 660,000 short tons) per '
# ...

# %% [markdown]
# As we can see, the retiever is working fine and gets us the context passage that contains the answer to our question. Now let's use the reader to extract the exact answer from the context passage.

# %%
extract_answer(question, context)
# Out:
# ...
#   QUESTION: How much oil is Egypt producing in a day?
# ...
#
#   Rank #1  |  Confidence: 100.00%
#   Answer: 691,000 bbl/d
#
#   Context (answer highlighted between --> <--):
#     Egypt was producing  -->691,000 bbl/d<--  of oil and 2,141.05 Tcf of
#     natural gas (in 2013), which makes Egypt as the largest oil producer
#     not member of the Organization of the Petroleum Exporting Countries
#     (OPEC) and the second-largest dry natural gas producer in Africa. In
#     2013, Egypt was the largest consumer of oil and natural gas in Africa,
#     as more than 20% of total oil consumption and more than 40% of total
#     dry natural gas consumption in Africa. Also, Egypt possesses the
#     largest oil refinery capacity in Africa 726,000 bbl/d (in 2012). Egypt
#     is currently planning to build its first nuclear power plant in El
#     Dabaa city, northern Egypt.
#
#   --------------------------------------------------------
#
#   Rank #2  |  Confidence: 0.00%
# ...

# %% [markdown]
# The reader model predicted with 99% accuracy the correct answer *691,000 bbl/d* as seen from the context passage. Let's run few more queries.

# %%
question = "What are the first names of the men that invented youtube?"
context = get_context(question, top_k=1)
extract_answer(question, context)
# Out:
# ...
#   QUESTION: What are the first names of the men that invented youtube?
# ...
#
#   Rank #1  |  Confidence: 99.99%
#   Answer: Hurley and Chen
#
#   Context (answer highlighted between --> <--):
#     According to a story that has often been repeated in the media,
#     -->Hurley and Chen<--  developed the idea for YouTube during the early
#     months of 2005, after they had experienced difficulty sharing videos
#     that had been shot at a dinner party at Chen's apartment in San
#     Francisco. Karim did not attend the party and denied that it had
#     occurred, but Chen commented that the idea that YouTube was founded
#     after a dinner party "was probably very strengthened by marketing
#     ideas around creating a story that was very digestible".
#
#   --------------------------------------------------------

# %%
question = "What is Albert Eistein famous for?"
context = get_context(question, top_k=1)
extract_answer(question, context)
# Out:
# ...
#   QUESTION: What is Albert Eistein famous for?
# ...
#
#   Rank #1  |  Confidence: 95.00%
#   Answer: his theories of special relativity and general relativity
#
#   Context (answer highlighted between --> <--):
#     Albert Einstein is known for  -->his theories of special relativity
#     and general relativity<-- . He also made important contributions to
#     statistical mechanics, especially his mathematical treatment of
#     Brownian motion, his resolution of the paradox of specific heats, and
#     his connection of fluctuations and dissipation. Despite his
#     reservations about its interpretation, Einstein also made
#     contributions to quantum mechanics and, indirectly, quantum field
#     theory, primarily through his theoretical studies of the photon.
#
#   --------------------------------------------------------

# %% [markdown]
# Let's run another question. This time for top 3 context passages from the retriever.

# %%
question = "Who was the first person to step foot on the moon?"
context = get_context(question, top_k=3)
extract_answer(question, context)
# Out:
# ...
#   QUESTION: Who was the first person to step foot on the moon?
# ...
#
#   Rank #1  |  Confidence: 99.98%
#   Answer: Armstrong
#
#   Context (answer highlighted between --> <--):
#     The trip to the Moon took just over three days. After achieving orbit,
#     -->Armstrong<--  and Aldrin transferred into the Lunar Module, named
#     Eagle, and after a landing gear inspection by Collins remaining in the
#     Command/Service Module Columbia, began their descent. After overcoming
#     several computer overload alarms caused by an antenna switch left in
#     the wrong position, and a slight downrange error, Armstrong took over
#     manual flight control at about 180 meters (590 ft), and guided the
#     Lunar Module to a safe landing spot at 20:18:04 UTC, July 20, 1969
#     (3:17:04 pm CDT). The first humans on the Moon would wait another six
#     hours before they ventured out of their craft. At 02:56 UTC, July 21
# ...

# %% [markdown]
# The result looks pretty good.

# %%
# Uncomment and use if space in Pinecone is low
#pc.delete_index(index_name)

# %% [markdown]
# ### Add a few more questions. What did you observe?

# %% [markdown]
# ## Questions where SQuAD almost certainly has strong coverage

# %%
# Factual / numerical
question = "How many chromosomes do humans have?"
context = get_context(question, top_k=3)
extract_answer(question, context)
# Out:
# ...
#   QUESTION: How many chromosomes do humans have?
# ...
#
#   Rank #1  |  Confidence: 0.01%
#   Answer: human genome
#
#   Context (answer highlighted between --> <--):
#     Both the number of base pairs and the number of genes vary widely from
#     one species to another, and there is only a rough correlation between
#     the two (an observation known as the C-value paradox). At present, the
#     highest known number of genes is around 60,000, for the protozoan
#     causing trichomoniasis (see List of sequenced eukaryotic genomes),
#     almost three times as many as in the  -->human genome<-- .
#
#   --------------------------------------------------------
#
#   Rank #2  |  Confidence: 0.00%
#   Answer: 2,000,000
#
#   Context (answer highlighted between --> <--):
#     Although the number of base-pairs of DNA in the human genome has been
#     known since the 1960s, the estimated number of genes has changed over
# ...

# %%
# Historical event with a clear date answer
question = "When did the Berlin Wall fall?"
context = get_context(question, top_k=1)
extract_answer(question, context)
# Out:
# ...
#   QUESTION: When did the Berlin Wall fall?
# ...
#
#   Rank #1  |  Confidence: 99.99%
#   Answer: 1989
#
#   Context (answer highlighted between --> <--):
#     Spring 1989 saw the people of the Soviet Union exercising a democratic
#     choice, albeit limited, for the first time since 1917, when they
#     elected the new Congress of People's Deputies. Just as important was
#     the uncensored live TV coverage of the legislature's deliberations,
#     where people witnessed the previously feared Communist leadership
#     being questioned and held accountable. This example fueled a limited
#     experiment with democracy in Poland, which quickly led to the toppling
#     of the Communist government in Warsaw that summer – which in turn
#     sparked uprisings that overthrew communism in the other five Warsaw
#     Pact countries before the end of  -->1989<-- , the year the Berlin
#     Wall fell. These events showed that the people of Eastern Europe and
# ...

# %%
# Science — well covered in Wikipedia
question = "What force keeps planets in orbit around the sun?"
context = get_context(question, top_k=3)
extract_answer(question, context)
# Out:
# ...
#   QUESTION: What force keeps planets in orbit around the sun?
# ...
#
#   Rank #1  |  Confidence: 0.43%
#   Answer: Jupiter's gravity
#
#   Context (answer highlighted between --> <--):
#     Neptune's orbit has a profound impact on the region directly beyond
#     it, known as the Kuiper belt. The Kuiper belt is a ring of small icy
#     worlds, similar to the asteroid belt but far larger, extending from
#     Neptune's orbit at 30 AU out to about 55 AU from the Sun. Much in the
#     same way that  -->Jupiter's gravity<--  dominates the asteroid belt,
#     shaping its structure, so Neptune's gravity dominates the Kuiper belt.
#     Over the age of the Solar System, certain regions of the Kuiper belt
#     became destabilised by Neptune's gravity, creating gaps in the Kuiper
#     belt's structure. The region between 40 and 42 AU is an example.
#
#   --------------------------------------------------------
#
#   Rank #2  |  Confidence: 0.13%
#   Answer: solar winds
#
# ...

# %% [markdown]
# ## Questions designed to stress-test the dataset

# %%
# The answer exists but the phrasing is indirect —
# "founded" vs "created" vs "established" tests lexical flexibility
question = "Who founded the Red Cross?"
context = get_context(question, top_k=3)
extract_answer(question, context)
# Out:
# ...
#   QUESTION: Who founded the Red Cross?
# ...
#
#   Rank #1  |  Confidence: 0.00%
#   Answer: Geneva is the birthplace of the Red Cross and Red Crescent Movement
#
#   Context (answer highlighted between --> <--):
#     A large number of international institutions have their seats in
#     Switzerland, in part because of its policy of neutrality.  -->Geneva
#     is the birthplace of the Red Cross and Red Crescent Movement<--  and
#     the Geneva Conventions and, since 2006, hosts the United Nations Human
#     Rights Council. Even though Switzerland is one of the most recent
#     countries to have joined the United Nations, the Palace of Nations in
#     Geneva is the second biggest centre for the United Nations after New
#     York, and Switzerland was a founding member and home to the League of
#     Nations.
#
#   --------------------------------------------------------
#
#   Rank #2  |  Confidence: 0.00%
#   Answer: Red Cross
#
#   Context (answer highlighted between --> <--):
# ...

# %%
# Multi-entity question — the reader has to extract a list, which
# extractive models handle less gracefully than single-span answers
question = "What are the main religions practiced in India?"
context = get_context(question, top_k=3)
extract_answer(question, context)
# Out:
# ...
#   QUESTION: What are the main religions practiced in India?
# ...
#
#   Rank #1  |  Confidence: 0.01%
#   Answer: )
#
#   Context (answer highlighted between --> <--):
#     Hinduism is the religion of 79.8% of New Delhi's population. There are
#     also communities of Muslims (12.9%), Sikhs (5.4%), Jains (1.1%) and
#     Christians (0.9% -->)<--  in Delhi. Other religious groups (2.5%)
#     include Parsis, Buddhists and Jews.
#
#   --------------------------------------------------------
#
#   Rank #2  |  Confidence: 0.00%
#   Answer: Indonesia
#
#   Context (answer highlighted between --> <--):
#     Religions and peoples are diverse in Southeast Asia and not one
#     country is homogeneous. In the world's most populous Muslim nation,
#     -->Indonesia<-- , Hinduism is dominant on islands such as Bali.
#     Christianity also predominates in the rest of the part of the
#     Philippines, New Guinea and Timor. Pockets of Hindu population can
# ...

# %%
# SQuAD was created in 2016 from Wikipedia articles of that era.
# Asking about something recent forces the system to guess from irrelevant context.
question = "Who won the FIFA World Cup in 2022?"
context = get_context(question, top_k=3)
extract_answer(question, context)
# Out:
# ...
#   QUESTION: Who won the FIFA World Cup in 2022?
# ...
#
#   Rank #1  |  Confidence: 0.00%
#   Answer: Al Ahly SC
#
#   Context (answer highlighted between --> <--):
#     On 11 August, Barcelona started the 2015–16 season winning a joint
#     record fifth European Super Cup by beating Sevilla FC 5–4 in the 2015
#     UEFA Super Cup. They ended the year with a 3–0 win over Argentine club
#     River Plate in the 2015 FIFA Club World Cup Final on 20 December to
#     win the trophy for a record third time, with Suárez, Messi and Iniesta
#     the top three players of the tournament. The FIFA Club World Cup was
#     Barcelona's 20th international title, a record only matched by
#     Egyptian club  -->Al Ahly SC<-- . By scoring 180 goals in 2015 in all
#     competitions, Barcelona set the record for most goals scored in a
#     calendar year, breaking Real Madrid's record of 178 goals scored in
#     2014.
#
#   --------------------------------------------------------
#
# ...

# %% [markdown]
# # Conclusion
#
# ## What We Built
#
# In this lab we implemented a full **extractive question answering pipeline** combining three components: a **Pinecone vector index** to store and search over context passages, a **SentenceTransformer retriever** (`multi-qa-MiniLM-L6-cos-v1`) to embed both passages and questions into a shared 384-dimensional semantic space, and an **ELECTRA reader** (`deepset/electra-base-squad2`) to extract precise answer spans from retrieved passages.
#
# Unlike the abstractive RAG system we built previously — where BART *generated* new text as an answer — this pipeline extracts answers that appear **verbatim** in the source corpus. The reader predicts a start and end token position within the passage, and the answer is always a direct quote from the original text.
#
# ---
#
# ## Key Findings
#
# **The two-stage retrieve-then-read architecture works well when the corpus has coverage.** When the right passage is retrieved, the ELECTRA reader is remarkably precise — returning spans like *"691,000 bbl/d"* or *"46"* with confidence scores above 99%. The clean separation between retrieval (finding the right passage) and extraction (finding the right span within it) makes the system easy to reason about and debug.
#
# **The confidence score is a meaningful and honest signal.** When the reader was handed an irrelevant passage, it didn't invent a plausible-sounding answer — it returned near-zero confidence alongside whatever span it was forced to extract. This makes the score actionable: a production system could filter responses below a threshold (e.g. 20%) and return *"I don't know"* instead of a confidently wrong answer.
#
# **Retrieval quality is the dominant factor in overall system quality.** The chromosome question demonstrated this definitively: when we bypassed the retriever and provided the correct passage directly, the reader answered with 99.88% confidence. The failure was never in the reader — it was entirely in what the retriever handed it. This confirms the principle established in the abstractive notebook: *poor answers in RAG systems are almost always caused by poor retrieval, not the generator.*
#
# **Corpus coverage sets a hard ceiling on system capability.** SQuAD's ~18,000 unique passages are drawn from a curated subset of Wikipedia articles. Facts that aren't represented in those articles — even well-known ones like the human chromosome count — are simply unreachable by the system, regardless of model quality. This is a data problem, not a model problem.
#
# ---
#
# ## Challenges Encountered
#
# **Dependency management in Colab required careful pinning.** The Pinecone package was renamed from `pinecone-client` to `pinecone`, causing an immediate import failure. More broadly, the HuggingFace stack (`transformers`, `sentence-transformers`, `huggingface_hub`, `tokenizers`) requires coordinated version pinning to avoid binary incompatibility errors — a lesson carried forward from the abstractive notebook.
#
# **GPU availability is not guaranteed and must be verified explicitly.** The embedding loop ran at ~15 seconds per batch when the retriever silently fell back to CPU, producing an estimated 74-minute runtime. Verifying `torch.cuda.is_available()` and `retriever.device` before starting the upsert loop is essential to catch this early.
#
# **The system has no "I don't know" capability out of the box.** The reader always returns *some* answer span, even when no passage contains the answer. This is a structural limitation of span-extraction models that requires an explicit post-processing layer — a confidence threshold filter — to handle gracefully in production.
#
# ---
#
# ## Suggested Improvements
#
# Expanding the indexed corpus beyond SQuAD's 18,000 passages would directly address the coverage gap. Adding a confidence threshold to suppress low-quality answers would make the system more trustworthy. A re-ranking layer between retrieval and reading — scoring passages for answer likelihood before passing them to ELECTRA — could further improve precision. Finally, replacing the ELECTRA reader with a generative model (such as Gemini via API) would allow the system to synthesise answers across multiple passages rather than being constrained to a single extracted span.
